# %% [markdown]
# # Install late_classifier library
#
# Installing requirements:
# - `pip install requirements_mhps.txt`
# - `pip install requirements_turbo_fats.txt`
# - `pip install requirements.txt`
#
# Install library for development:
# - `pip install -e .`

# %%
from late_classifier.features import CustomHierarchicalExtractor
from late_classifier.features import DetectionsPreprocessorZTF
import pandas as pd

# %% [markdown]
# # Init our magic tools

# %%
preprocess_ztf = DetectionsPreprocessorZTF()
extractor = CustomHierarchicalExtractor()

# %% [markdown]
# # Getting/prepare data

# %%
detections = pd.read_parquet("/home/javier/Downloads/corrected_0.parquet")
non_detections = pd.read_parquet("/home/javier/Downloads/non_detections_0.pickle",
                                columns=["objectId", "fid", "jd", "diffmaglim"])
objects = pd.read_parquet("/home/javier/Downloads/objstats_0.parquet")

non_detections["mjd"] = non_detections["jd"] - 2400000.5

detections.reset_index(inplace=True)
detections.set_index("objectId", inplace=True)
detections.index.name = 'oid'

non_detections.set_index("objectId", inplace=True)
non_detections.index.name = 'oid'

objects.index.name = 'oid'

#display(detections)
#display(non_detections)
#display(objects)

# %% [markdown]
# # Preprocess data

# %%
#det_preprocess = preprocess_ztf.preprocess(detections[:10000], objects=objects)
#display(det_preprocess[~det_preprocess.corrected.values])

# %% [markdown]
# # Compute features

# %%
features_df = extractor.compute_features(
    detections=detections[:5000],
    non_detections=non_detections,
    objects=objects
    )
display(features_df)
# Out:
#  /home/javier/Desktop/ALeRCE/late_classifier/late_classifier/features/extractors/mhps_extractor.py:54: RuntimeWarning:invalid value encountered in true_divide
#  /home/javier/Desktop/ALeRCE/late_classifier/src/turbo-fats/turbofats/features/structure_function.py:88: RuntimeWarning:invalid value encountered in sqrt
#  /home/javier/Desktop/ALeRCE/late_classifier/src/turbo-fats/turbofats/features/structure_function.py:97: RuntimeWarning:invalid value encountered in greater
#  /home/javier/Desktop/ALeRCE/late_classifier/src/turbo-fats/turbofats/features/structure_function.py:88: RuntimeWarning:invalid value encountered in sqrt
#  /home/javier/Desktop/ALeRCE/late_classifier/src/turbo-fats/turbofats/features/structure_function.py:97: RuntimeWarning:invalid value encountered in greater
#  /home/javier/anaconda3/envs/late_classifier/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning:Covariance of the parameters could not be estimated
#               Amplitude_1  Amplitude_2  AndersonDarling_1  AndersonDarling_2  \
# ZTF17aaaaavn     0.087899     0.098188           0.918219           0.867602
# ZTF17aaaadjh     0.493980     0.463765           1.000000           1.000000
# ZTF17aaaadwo     0.090708          NaN           0.903625                NaN
# ZTF17aaaajjv     0.538815     0.411638           1.000000           0.999938
# ZTF17aaaakjt     0.570429     0.325192           0.995635           0.338907
# ZTF17aaaaneq     0.187539     0.255238           0.981926           0.999051
# ZTF17aaabmwq     0.393668          NaN           0.999665                NaN
# ZTF17aaabrhj     0.107790     0.102744           0.863897           0.872233
# ZTF17aaabxwz     0.216228     0.203637           1.000000           1.000000
# ZTF17aaabyfh     0.228270     0.163769           1.000000           1.000000
# ZTF17aaaccnn     0.230826     0.204615           0.999985           0.999999
# ZTF17aaadydh     1.847830     1.654228           0.999959           0.999510
# ZTF17aaaeaiv     0.244182     0.211269           0.995820           1.000000
# ZTF17aaaecgt     0.783723     0.833980           1.000000           1.000000
# ZTF17aaaedhn     0.810894     0.602102           1.000000           1.000000
# ZTF17aaaedla     0.312123     0.298324           1.000000           1.000000
# ZTF17aaaadjh  0.00000  0.000000  ...                    130
# ZTF17aaaadwo  0.00000       NaN  ...                    133
# ZTF17aaaajjv  0.05102  0.000000  ...                    132
# ZTF17aaaakjt  0.00000  0.000000  ...                     88
# ZTF17aaaaneq  0.00000  0.000000  ...                     42
# ZTF17aaabmwq  0.00000       NaN  ...                    164
# ZTF17aaabrhj  0.00000  0.000000  ...                    219
# ZTF17aaabxwz  0.00000  0.000000  ...                    143
# ZTF17aaabyfh  0.00000  0.000000  ...                     37
# ZTF17aaaccnn  0.00000  0.000000  ...                     43
# ZTF17aaadydh  0.00000  0.000000  ...                    115
# ZTF17aaaeaiv  0.00000  0.000000  ...                    153
# ZTF17aaaecgt  0.00000  0.000000  ...                     63
# ZTF17aaaedhn  0.00000  0.006515  ...                    515
# ZTF17aaaedla  0.00000  0.000000  ...                     90
# ZTF17aaaehxj  0.00000  0.000000  ...                     71
# ZTF17aaaekat  0.00000  0.000000  ...                    204
# ZTF17aaaenfa  0.00000  0.000000  ...                     81
# ZTF17aaafgpk  0.00000  0.000000  ...                    135
# ZTF17aaagrmf  0.00000  0.000000  ...                    225
# ZTF17aaagrtv  0.00000  0.000000  ...                     27
# ZTF17aaagzav  0.00000  0.000000  ...                     16
# ZTF17aaahnws  0.00000  0.000000  ...                     30
# ZTF17aaahtbn  0.00000  0.000000  ...                     21
# ZTF17aaaiohv  0.00000  0.000000  ...                     36
# ZTF17aaairio  0.00000  0.000000  ...                     64
# ZTF17aaajgcp  0.00000  0.000000  ...                     16
# ZTF17aaajgxv  0.00000  0.000000  ...                     19
# ZTF17aaajsun  0.00000       NaN  ...                     62
# ZTF17aaanqim  0.00000       NaN  ...                     42
# ZTF17aaanqxw  0.00000  0.000000  ...                     34
# ZTF17aaanymx  0.00000       NaN  ...                     69
#
#               n_non_det_after_fid_2  n_non_det_before_fid_1  \
# ZTF17aaaaavn                    284                       9
# ZTF17aaaadjh                    111                       1
# ZTF17aaaadwo                     85                       0
# ZTF17aaaajjv                    108                       5
# ZTF17aaaakjt                     93                       5
# ZTF17aaaaneq                     39                      24
# ZTF17aaabmwq                    213                      13
# ZTF17aaabrhj                    229                      21
# ZTF17aaabxwz                    118                       2
# ZTF17aaabyfh                     47                       3
# ZTF17aaaccnn                     42                       6
# ZTF17aaadydh                    121                       6
# ZTF17aaaeaiv                    146                      24
# ZTF17aaaecgt                    124                       0
# ZTF17aaaedhn                    285                      14
# ZTF17aaaedla                    110                       2
# ZTF17aaaehxj                     74                       4
# ZTF17aaaekat                    118                       0
# ZTF17aaaenfa                     71                       1
# ZTF17aaafgpk                     97                       1
# ZTF17aaagrmf                    176                       1
# ZTF17aaagrtv                     13                       3
# ZTF17aaagzav                     12                       0
# ZTF17aaahnws                     26                       2
# ZTF17aaahtbn                     25                       1
# ZTF17aaaiohv                    166                       0
# ZTF17aaairio                     59                       2
# ZTF17aaajgcp                     24                       2
# ZTF17aaajgxv                     30                       4
# ZTF17aaajsun                     64                       0
# ZTF17aaanqim                    NaN                       5
# ZTF17aaanqxw                     24                       0
# ZTF17aaanymx                     20                       0
#
#               n_non_det_before_fid_2  n_pos_1  n_pos_2  positive_fraction_1  \
# ZTF17aaaaavn                      34        0        0             0.000000
# ZTF17aaaadjh                       0       21       23             0.488372
# ZTF17aaaadwo                      39        0        4             0.000000
# ZTF17aaaajjv                      13        7        1             0.070000
