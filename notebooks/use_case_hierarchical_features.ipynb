# %% [markdown]
# # Install late_classifier library
#
# Installing requirements:
# - `pip install requirements_mhps.txt`
# - `pip install requirements_turbo_fats.txt`
# - `pip install requirements.txt`
#
# Install library for development:
# - `pip install -e .`

# %%
from late_classifier.features import CustomHierarchicalExtractor
from late_classifier.features import DetectionsPreprocessorZTF
import pandas as pd

# %% [markdown]
# # Init our magic tools

# %%
preprocess_ztf = DetectionsPreprocessorZTF()
extractor = CustomHierarchicalExtractor()

# %% [markdown]
# # Getting/prepare data

# %%
detections = pd.read_parquet("/home/javier/Downloads/corrected_0.parquet")
non_detections = pd.read_parquet("/home/javier/Downloads/non_detections_0.pickle",
                                columns=["objectId", "fid", "jd", "diffmaglim"])
objects = pd.read_parquet("/home/javier/Downloads/objstats_0.parquet")

non_detections["mjd"] = non_detections["jd"] - 2400000.5

detections.reset_index(inplace=True)
detections.set_index("objectId", inplace=True)
detections.index.name = 'oid'

non_detections.set_index("objectId", inplace=True)
non_detections.index.name = 'oid'

objects.index.name = 'oid'

display(detections)
display(non_detections)
display(objects)
# Out:
#               fid               candid            pid  diffmaglim  \
# oid
# ZTF17aaaaavn    1  1218476313215010007  1218476313215   20.848171
# ZTF17aaaaavn    1   525449494515010015   525449494515   20.658161
# ZTF17aaaaavn    1  1238482763215010009  1238482763215   19.979372
# ZTF17aaaaavn    1   890455934515010013   890455934515   20.741301
# ZTF17aaaaavn    1   993188273215010013   993188273215   20.804922
# ...           ...                  ...            ...         ...
# ZTF20abehuri    1  1256463335515015013  1256463335515   20.008762
# ZTF20abehusc    1  1256463334015010001  1256463334015   19.974495
# ZTF20abehuxo    1  1256466624615015007  1256466624615   19.998283
# ZTF20abehvrz    1  1256474683715015004  1256474683715   19.888363
# ZTF20abehwjf    1  1256478473115015014  1256478473115   20.012602
#
#                                                 pdiffimfilename programpi  \
# oid
# ZTF17aaaaavn  ztf_20200503476308_000768_zg_c09_o_q1_scimrefd...  Kulkarni
# ZTF17aaaaavn  ztf_20180610449468_000769_zg_c12_o_q2_scimrefd...  Kulkarni
# ZTF17aaaaavn  ztf_20200523482766_000768_zg_c09_o_q1_scimrefd...  Kulkarni
# ZTF17aaaaavn  ztf_20190610455903_000769_zg_c12_o_q2_scimrefd...  Kulkarni
# ZTF17aaaaavn  ztf_20190921188241_000768_zg_c09_o_q1_scimrefd...      TESS
# ...                                                         ...       ...
# ZTF20abehuri  ztf_20200610463333_000593_zg_c14_o_q4_scimrefd...  Kulkarni
# ZTF20abehusc  ztf_20200610463333_000593_zg_c11_o_q1_scimrefd...  Kulkarni
# ZTF20abehuxo  ztf_20200610466620_000596_zg_c12_o_q3_scimrefd...  Kulkarni
# ZTF20abehvrz  ztf_20200610474676_000853_zg_c10_o_q2_scimrefd...  Kulkarni
# ZTF20abehwjf  ztf_20200610478472_000730_zg_c08_o_q4_scimrefd...  Kulkarni
#
#               programid  isdiffpos  tblid   nid  ...    jdstartref  \
# oid                                              ...
# ZTF17aaaaavn          1       -1.0      7  1218  ...  2.458207e+06
# ZTF17aaaaavn          1       -1.0     15   525  ...  2.458229e+06
# ZTF17aaaaavn          1       -1.0      9  1238  ...  2.458207e+06
# ZTF17aaaaavn          1       -1.0     13   890  ...  2.458229e+06
# ZTF17aaaaavn          1       -1.0     13   993  ...  2.458207e+06
# ...                 ...        ...    ...   ...  ...           ...
# ZTF20abehuri          1        1.0     13  1256  ...  2.458231e+06
# ZTF20abehusc          1       -1.0      1  1256  ...  2.458231e+06
# ZTF20abehuxo          1        1.0      7  1256  ...  2.458248e+06
# ZTF20abehvrz          1        1.0      4  1256  ...  2.458256e+06
# ZTF20abehwjf          1        1.0     14  1256  ...  2.458230e+06
#
#                   jdendref  nframesref  parent_candid           mjd  \
# oid
# ZTF17aaaaavn  2.458274e+06          15              0  58972.476319
# ZTF17aaaaavn  2.458274e+06          15              0  58279.449491
# ZTF17aaaaavn  2.458274e+06          15              0  58992.482766
# ZTF17aaaaavn  2.458274e+06          15              0  58644.455938
# ZTF17aaaaavn  2.458274e+06          15              0  58747.188276
# ...                    ...         ...            ...           ...
# ZTF20abehuri  2.458323e+06          15              0  59010.463333
# ZTF20abehusc  2.458323e+06          15              0  59010.463333
# ZTF20abehuxo  2.458288e+06          15              0  59010.466620
# ZTF20abehvrz  2.458344e+06          15              0  59010.474687
# ZTF20abehwjf  2.458283e+06          15              0  59010.478472
#
#               corrected  magpsf_corr  sigmapsf_corr  sigmapsf_corr_ext  \
# oid
# ZTF17aaaaavn       True    18.242198       0.050150           0.054709
# ZTF17aaaaavn       True    18.214681     100.000000           0.026414
# ZTF17aaaaavn       True    18.294830       0.055089           0.059678
# ZTF17aaaaavn       True    18.233564       0.028152           0.040530
# ZTF17aaaaavn       True    18.276458       0.041666           0.047384
# ...                 ...          ...            ...                ...
# ZTF20abehuri       True    12.473168     100.000000           0.001357
# ZTF20abehusc       True    14.159516     100.000000           0.006202
# ZTF20abehuxo      False          NaN            NaN                NaN
# ZTF20abehvrz      False          NaN            NaN                NaN
# ZTF20abehwjf      False          NaN            NaN                NaN
#
#               dubious
# oid
# ZTF17aaaaavn    False
# ZTF17aaaaavn    False
# ZTF17aaaaavn    False
# ZTF17aaaaavn    False
# ZTF17aaaaavn    False
# ...               ...
# ZTF20abehuri    False
# ZTF20abehusc    False
# ZTF20abehuxo    False
# ZTF20abehvrz    False
# ZTF20abehwjf    False
#
# [355289 rows x 88 columns]
#               fid            jd  diffmaglim           mjd
# oid
# ZTF17aaaaavn    2  2.458722e+06   20.054899  58721.262373
# ZTF17aaafjzk    1  2.458748e+06   20.147900  58747.330729
# ZTF17aaakptm    2  2.458801e+06   19.122200  58800.315833
# ZTF17aaanqim    1  2.458508e+06   20.164900  58507.204178
# ZTF17aaanqim    2  2.458791e+06   20.377800  58790.505972
# ...           ...           ...         ...           ...
# ZTF20abdswmh    1  2.458977e+06   19.499599  58976.458796
# ZTF20abdtnmg    1  2.458993e+06   20.722000  58992.475718
# ZTF20abdxhos    2  2.458981e+06   20.431801  58980.285660
# ZTF20abdzhlu    2  2.458978e+06   19.570000  58977.471204
# ZTF20abealgg    1  2.458981e+06   19.838400  58980.402859
#
# [3451937 rows x 4 columns]
#               nearZTF  nearPS1  stellar  corrected  ndet  ndubious
# oid
# ZTF17aaaaavn     True     True     True       True    50         0
# ZTF17aaaadjh     True     True     True       True   121         3
# ZTF17aaaadwo     True     True     True       True    35         0
# ZTF17aaaafmt     True     True     True       True     1         0
# ZTF17aaaafvw     True     True     True       True     2         0
# ...               ...      ...      ...        ...   ...       ...
# ZTF20abehuri     True     True     True       True     1         0
# ZTF20abehusc     True     True     True       True     1         0
# ZTF20abehuxo    False    False    False      False     1         0
# ZTF20abehvrz    False    False    False      False     1         0
# ZTF20abehwjf    False    False    False      False     1         0
#
# [117130 rows x 6 columns]

# %% [markdown]
# # Preprocess data

# %%
det_preprocess = preprocess_ztf.preprocess(detections)
display(det_preprocess)
# Out:
#               fid               candid            pid  diffmaglim  \
# oid
# ZTF17aaaaavn    1  1218476313215010007  1218476313215   20.848171
# ZTF17aaaaavn    1   525449494515010015   525449494515   20.658161
# ZTF17aaaaavn    1  1238482763215010009  1238482763215   19.979372
# ZTF17aaaaavn    1   890455934515010013   890455934515   20.741301
# ZTF17aaaaavn    1   993188273215010013   993188273215   20.804922
# ...           ...                  ...            ...         ...
# ZTF20aaxyapk    1  1208496122415010021  1208496122415   20.635000
# ZTF20aaxyapk    1  1209458142415010030  1209458142415   20.735600
# ZTF20aaxyapk    1  1211422752415010019  1211422752415   20.959900
# ZTF20aaxyapk    1  1219451702415010009  1219451702415   20.092100
# ZTF20aaxyapk    1  1214463852415010015  1214463852415   20.952999
#
#                                                 pdiffimfilename programpi  \
# oid
# ZTF17aaaaavn  ztf_20200503476308_000768_zg_c09_o_q1_scimrefd...  Kulkarni
# ZTF17aaaaavn  ztf_20180610449468_000769_zg_c12_o_q2_scimrefd...  Kulkarni
# ZTF17aaaaavn  ztf_20200523482766_000768_zg_c09_o_q1_scimrefd...  Kulkarni
# ZTF17aaaaavn  ztf_20190610455903_000769_zg_c12_o_q2_scimrefd...  Kulkarni
# ZTF17aaaaavn  ztf_20190921188241_000768_zg_c09_o_q1_scimrefd...      TESS
# ...                                                         ...       ...
# ZTF20aaxyapk  /ztf/archive/sci/2020/0423/496100/ztf_20200423...      TESS
# ZTF20aaxyapk  /ztf/archive/sci/2020/0424/458148/ztf_20200424...      TESS
# ZTF20aaxyapk  /ztf/archive/sci/2020/0426/422743/ztf_20200426...      TESS
# ZTF20aaxyapk  /ztf/archive/sci/2020/0504/451701/ztf_20200504...      TESS
# ZTF20aaxyapk  /ztf/archive/sci/2020/0429/463762/ztf_20200429...      TESS
#
#               programid  isdiffpos  tblid   nid  ...    jdstartref  \
# oid                                              ...
# ZTF17aaaaavn          1       -1.0      7  1218  ...  2.458207e+06
# ZTF17aaaaavn          1       -1.0     15   525  ...  2.458229e+06
# ZTF17aaaaavn          1       -1.0      9  1238  ...  2.458207e+06
# ZTF17aaaaavn          1       -1.0     13   890  ...  2.458229e+06
# ZTF17aaaaavn          1       -1.0     13   993  ...  2.458207e+06
# ...                 ...        ...    ...   ...  ...           ...
# ZTF20aaxyapk          1       -1.0     21  1208  ...  2.458206e+06
# ZTF20aaxyapk          1       -1.0     30  1209  ...  2.458206e+06
# ZTF20aaxyapk          1       -1.0     19  1211  ...  2.458206e+06
# ZTF20aaxyapk          1       -1.0      9  1219  ...  2.458206e+06
# ZTF20aaxyapk          1       -1.0     15  1214  ...  2.458206e+06
#
#                   jdendref  nframesref        parent_candid           mjd  \
# oid
# ZTF17aaaaavn  2.458274e+06          15                    0  58972.476319
# ZTF17aaaaavn  2.458274e+06          15                    0  58279.449491
# ZTF17aaaaavn  2.458274e+06          15                    0  58992.482766
# ZTF17aaaaavn  2.458274e+06          15                    0  58644.455938
# ZTF17aaaaavn  2.458274e+06          15                    0  58747.188276
# ...                    ...         ...                  ...           ...
# ZTF20aaxyapk  2.458233e+06          16  1238354152415010026  58962.496123
# ZTF20aaxyapk  2.458233e+06          16  1238354152415010026  58963.458148
# ZTF20aaxyapk  2.458233e+06          16  1241327182415010011  58965.422755
# ZTF20aaxyapk  2.458233e+06          16  1241327182415010011  58973.451701
# ZTF20aaxyapk  2.458233e+06          16  1241327182415010011  58968.463854
#
#               corrected  magpsf_corr  sigmapsf_corr  sigmapsf_corr_ext  \
# oid
# ZTF17aaaaavn       True    18.242198       0.050150           0.054709
# ZTF17aaaaavn       True    18.214681     100.000000           0.026414
# ZTF17aaaaavn       True    18.294830       0.055089           0.059678
# ZTF17aaaaavn       True    18.233564       0.028152           0.040530
# ZTF17aaaaavn       True    18.276458       0.041666           0.047384
# ...                 ...          ...            ...                ...
# ZTF20aaxyapk       True    19.123037       0.067999           0.071421
# ZTF20aaxyapk       True    19.122163       0.060203           0.064037
# ZTF20aaxyapk       True    19.104102       0.061401           0.065045
# ZTF20aaxyapk       True    19.252149       0.096071           0.099170
# ZTF20aaxyapk       True    19.152722       0.061355           0.065333
#
#               dubious
# oid
# ZTF17aaaaavn    False
# ZTF17aaaaavn    False
# ZTF17aaaaavn    False
# ZTF17aaaaavn    False
# ZTF17aaaaavn    False
# ...               ...
# ZTF20aaxyapk    False
# ZTF20aaxyapk    False
# ZTF20aaxyapk    False
# ZTF20aaxyapk    False
# ZTF20aaxyapk    False
#
# [138451 rows x 88 columns]

# %% [markdown]
# # Compute features

# %%
features_df = extractor.compute_features(
    detections=det_preprocess,
    non_detections=non_detections,
    objects=objects,
    )
display(features_df)

# %%
det_preprocess.groupby("oid").apply(lambda x: x)

# %%
detections.index.unique()
# Out:
# Index(['ZTF17aaaaavn', 'ZTF17aaaadjh', 'ZTF17aaaadwo', 'ZTF17aaaafmt',
#        'ZTF17aaaafvw', 'ZTF17aaaahdc', 'ZTF17aaaahed', 'ZTF17aaaahev',
#        'ZTF17aaaaisg', 'ZTF17aaaajjv',
#        ...
#        'ZTF20abegnyu', 'ZTF20abegnzh', 'ZTF20abegpbi', 'ZTF20abegpmr',
#        'ZTF20abehuqt', 'ZTF20abehuri', 'ZTF20abehusc', 'ZTF20abehuxo',
#        'ZTF20abehvrz', 'ZTF20abehwjf'],
#       dtype='object', name='oid', length=117130)

# %%
det_preprocess.index.unique()
# Out:
# Index(['ZTF17aaaaavn', 'ZTF17aaaadjh', 'ZTF17aaaadwo', 'ZTF17aaaajjv',
#        'ZTF17aaaakjt', 'ZTF17aaaaneq', 'ZTF17aaabbhy', 'ZTF17aaabmwq',
#        'ZTF17aaabrhj', 'ZTF17aaabxwz',
#        ...
#        'ZTF20aavtcyk', 'ZTF20aavykbs', 'ZTF20aavykps', 'ZTF20aawidws',
#        'ZTF20aawihcm', 'ZTF20aawikmx', 'ZTF20aawipth', 'ZTF20aawjkyj',
#        'ZTF20aawwgpw', 'ZTF20aaxyapk'],
#       dtype='object', name='oid', length=3280)
